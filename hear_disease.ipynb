# %% [markdown]
# #Heart Disease prediction

# %%
# now importing pandas to import the data file 
import pandas as pd

# %%
df = pd.read_csv("heart_disease_sample (1).csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       0

# %%
# now a graph 
 df.target.value_counts().plot(kind="bar")
# Out:
#   Cell In[11], line 2
#     df.target.value_counts().plot(kind="bar")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# but this will not show the graph because you only imported pandas but there is not matplotlib

# %%
 import matplotlib.pyplot as plt

# %%
df.target.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='target'>

# %% [markdown]
# ![](ChatGPT Image Dec 18, 2025, 10_48_03 AM.png)

# %% [markdown]
# ![](image.png)

# %% [markdown]
# # In this pitcure it was not there but there are 6 steps in data modelling
#   1. problem defnition
#   2. data
#   3. evaluation
#   4. features
#   5. modelling
#   6. experimentation
#   now lets have each cell for each one of these

# %% [markdown]
# # 1. Problem Definition
#     predict heart disease

# %% [markdown]
# # 2. Data
#     This is data we're using

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 4E95-D3C8
#
#  Directory of C:\Users\pardh\OneDrive\Desktop\sample_project
#
# 18-12-2025  10:56    <DIR>          .
# 17-12-2025  10:31    <DIR>          ..
# 18-12-2025  10:30    <DIR>          .ipynb_checkpoints
# 16-12-2025  22:22    <DIR>          env
# 18-12-2025  10:33               450 heart_disease_sample (1).csv
# 18-12-2025  10:48           666,841 image.png
# 18-12-2025  10:30             2,805 Untitled.ipynb
# 18-12-2025  10:56            17,804 Untitled1.ipynb
#                4 File(s)        687,900 bytes
#                4 Dir(s)  221,054,644,224 bytes free

# %%
# !ls
# Out:
# Untitled.ipynb
# Untitled1.ipynb
# env
# heart_disease_sample (1).csv
# image.png
