# %%
print("hello pardhuva")
# Out:
# hello pardhuva

# %%
print("lets start")
# Out:
# lets start

# %% [markdown]
# Hello World

# %%
a=5

# %%
a
# Out:
# 5

# %%
1+1
# Out:
# 2

# %%
## heart disease prediction 
2+3
# Out:
# 5

# %%
import pandas as pd
